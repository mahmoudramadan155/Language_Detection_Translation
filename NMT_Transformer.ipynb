# %% [markdown]
# # **Fine Tuning NMT Transformer**

# %% [markdown]
# ## models names

# %%
# Helsinki-NLP/opus-mt-tc-big-en-ar
# Helsinki-NLP/opus-mt-tc-big-ar-en
# Helsinki-NLP/opus-mt-en-ar
# marefa-nlp/marefa-mt-ar-en

# %% [markdown]
# ## Installing Dependencies

# %%
#! pip install --trusted-host pypi.org --trusted-host pypi.python.org --trusted-host files.pythonhosted.org <package_name>

# %%
! pip install datasets sacrebleu torch transformers sentencepiece transformers[sentencepiece]

# %%
! pip install accelerate -U

# %% [markdown]
# ## Required Imports

# %%
import warnings
import numpy as np
import pandas as pd

import torch
import transformers

from datasets import Dataset, load_metric

from tqdm import tqdm
from transformers import AutoTokenizer
from sklearn.model_selection import train_test_split
from transformers import T5Tokenizer, T5ForConditionalGeneration, AutoModelForSeq2SeqLM
from transformers import DataCollatorForSeq2Seq, Seq2SeqTrainingArguments, Seq2SeqTrainer

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Constants

# %%
BATCH_SIZE = 16
BLEU = "bleu"
ENGLISH = "en"
ENGLISH_TEXT = "English"
EPOCH = "epoch"
INPUT_IDS = "input_ids"
FILENAME = "translation_train.csv"
GEN_LEN = "gen_len"
MAX_INPUT_LENGTH = 128
MAX_TARGET_LENGTH = 128
MODEL_CHECKPOINT = "Helsinki-NLP/opus-mt-ar-en"
MODEL_NAME = MODEL_CHECKPOINT.split("/")[-1]
LABELS = "labels"
PREFIX = ""
PORTUGUESE = "ar"
PORTUGUESE_TEXT = "Arabic"
SCORE = "score"
SOURCE_LANG = "ar"
TARGET_LANG = "en"
TRANSLATION = "translation"

# %% [markdown]
# ## Helper Functions

# %%
def postprocess_text(preds: list, labels: list) -> tuple:
    """Performs post processing on the prediction text and labels"""

    preds = [pred.strip() for pred in preds]
    labels = [[label.strip()] for label in labels]

    return preds, labels


def prep_data_for_model_fine_tuning(source_lang: list, target_lang: list) -> list:
    """Takes the input data lists and converts into translation list of dicts"""

    data_dict = dict()
    data_dict[TRANSLATION] = []

    for sr_text, tr_text in zip(source_lang, target_lang):
        temp_dict = dict()
        temp_dict[PORTUGUESE] = sr_text
        temp_dict[ENGLISH] = tr_text

        data_dict[TRANSLATION].append(temp_dict)

    return data_dict


def generate_model_ready_dataset(dataset: list, source: str, target: str,
                                 model_checkpoint: str,
                                 tokenizer: AutoTokenizer):
    """Makes the data training ready for the model"""

    preped_data = []

    for row in dataset:
        inputs = PREFIX + row[source]
        targets = row[target]

        model_inputs = tokenizer(inputs, max_length=MAX_INPUT_LENGTH,
                                 truncation=True, padding=True)

        model_inputs[TRANSLATION] = row

        # setup the tokenizer for targets
        with tokenizer.as_target_tokenizer():
            labels = tokenizer(targets, max_length=MAX_INPUT_LENGTH,
                                 truncation=True, padding=True)
            model_inputs[LABELS] = labels[INPUT_IDS]

        preped_data.append(model_inputs)

    return preped_data



def compute_metrics(eval_preds: tuple) -> dict:
    """computes bleu score and other performance metrics """

    metric = load_metric("sacrebleu")
    tokenizer = AutoTokenizer.from_pretrained(MODEL_CHECKPOINT)

    preds, labels = eval_preds

    if isinstance(preds, tuple):
        preds = preds[0]

    decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)

    # Replace -100 in the labels as we can't decode them.
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    # Some simple post-processing
    decoded_preds, decoded_labels = postprocess_text(decoded_preds, decoded_labels)

    result = metric.compute(predictions=decoded_preds, references=decoded_labels)
    result = {BLEU: result[SCORE]}

    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in preds]

    result[GEN_LEN] = np.mean(prediction_lens)
    result = {k: round(v, 4) for k, v in result.items()}

    return result

# %% [markdown]
# ## Loading and Preparing The Dataset

# %%
translation_data = pd.read_csv(FILENAME)
translation_data.head()
# Out:
#                                              English  \
# 0                       I have been dealt four aces.
# 1                          rejoice over the verdict.
# 2  today the people of south africa marched in su...
# 3  earlier this month the ministry of health decl...
# 4  sharek posted this video titled sharek partici...
#
#                                               Arabic
# 0                     لقد رميت اربع اوراق من نوع أس.
# 1                           ابتهاج نتيجة اصدار الحكم
# 2  اليوم شعب جنوب افريقيا يدعم الفلسطينيين الذين ...
# 3  وقد صرحت وزارة الصحة باكرا هذا الشهر ان اكثر م...
# 4  نشر هذا الفيديو تحت عنوان شارك داعيا الشعب للا...

# %% [markdown]
# ## Train, Test & Validation Split of Data

# %%
X = translation_data[PORTUGUESE_TEXT]
y = translation_data[ENGLISH_TEXT]

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.10, shuffle=True, random_state=100)

print("INITIAL X-TRAIN SHAPE: ", x_train.shape)
print("INITIAL Y-TRAIN SHAPE: ", y_train.shape)
print("X-TEST SHAPE: ", x_test.shape)
print("Y-TEST SHAPE: ", y_test.shape)
# Out:
# INITIAL X-TRAIN SHAPE:  (21065,)
# INITIAL Y-TRAIN SHAPE:  (21065,)
# X-TEST SHAPE:  (2341,)
# Y-TEST SHAPE:  (2341,)

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.20, shuffle=True, random_state=100)

print("FINAL X-TRAIN SHAPE: ", x_train.shape)
print("FINAL Y-TRAIN SHAPE: ", y_train.shape)
print("X-VAL SHAPE: ", x_val.shape)
print("Y-VAL SHAPE: ", y_val.shape)
# Out:
# FINAL X-TRAIN SHAPE:  (16852,)
# FINAL Y-TRAIN SHAPE:  (16852,)
# X-VAL SHAPE:  (4213,)
# Y-VAL SHAPE:  (4213,)

# %% [markdown]
# ## Load Tokenizer from AutoTokenizer Class

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_CHECKPOINT)

# %% [markdown]
# ## Prepare the model ready dataset

# %%
training_data = prep_data_for_model_fine_tuning(x_train.values, y_train.values)

validation_data = prep_data_for_model_fine_tuning(x_val.values, y_val.values)

test_data = prep_data_for_model_fine_tuning(x_test.values, y_test.values)

# %%
train_data = generate_model_ready_dataset(dataset=training_data[TRANSLATION],
                                          tokenizer=tokenizer,
                                          source=PORTUGUESE,
                                          target=ENGLISH,
                                          model_checkpoint=MODEL_CHECKPOINT)

validation_data = generate_model_ready_dataset(dataset=validation_data[TRANSLATION],
                                               tokenizer=tokenizer,
                                               source=PORTUGUESE,
                                               target=ENGLISH,
                                               model_checkpoint=MODEL_CHECKPOINT)

test_data = generate_model_ready_dataset(dataset=test_data[TRANSLATION],
                                               tokenizer=tokenizer,
                                               source=PORTUGUESE,
                                               target=ENGLISH,
                                               model_checkpoint=MODEL_CHECKPOINT)

# %%
train_df = pd.DataFrame.from_records(train_data)
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16852 entries, 0 to 16851
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   attention_mask  16852 non-null  object
#  1   input_ids       16852 non-null  object
#  2   labels          16852 non-null  object
#  3   translation     16852 non-null  object
# dtypes: object(4)
# memory usage: 526.8+ KB

# %%
validation_df = pd.DataFrame.from_records(validation_data)
validation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4213 entries, 0 to 4212
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   attention_mask  4213 non-null   object
#  1   input_ids       4213 non-null   object
#  2   labels          4213 non-null   object
#  3   translation     4213 non-null   object
# dtypes: object(4)
# memory usage: 131.8+ KB

# %%
test_df = pd.DataFrame.from_records(test_data)
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2341 entries, 0 to 2340
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   attention_mask  2341 non-null   object
#  1   input_ids       2341 non-null   object
#  2   labels          2341 non-null   object
#  3   translation     2341 non-null   object
# dtypes: object(4)
# memory usage: 73.3+ KB

# %% [markdown]
# ## Convert dataframe to Dataset Class object

# %%
train_dataset = Dataset.from_pandas(train_df)
train_dataset
# Out:
# Dataset({
#     features: ['attention_mask', 'input_ids', 'labels', 'translation'],
#     num_rows: 16852
# })

# %%
validation_dataset = Dataset.from_pandas(validation_df)
validation_dataset
# Out:
# Dataset({
#     features: ['attention_mask', 'input_ids', 'labels', 'translation'],
#     num_rows: 4213
# })

# %%
test_dataset = Dataset.from_pandas(test_df)
test_dataset
# Out:
# Dataset({
#     features: ['attention_mask', 'input_ids', 'labels', 'translation'],
#     num_rows: 2341
# })

# %% [markdown]
# ## Load model, Create Model Training Args and Data Collator

# %%
model = AutoModelForSeq2SeqLM.from_pretrained(MODEL_CHECKPOINT)

# %%
model_args = Seq2SeqTrainingArguments(
    f"{MODEL_NAME}-finetuned-{SOURCE_LANG}-to-{TARGET_LANG}",
    evaluation_strategy=EPOCH,
    learning_rate=2e-4,
    per_device_train_batch_size=BATCH_SIZE,
    per_device_eval_batch_size=BATCH_SIZE,
    weight_decay=0.02,
    save_total_limit=3,
    num_train_epochs=2,
    predict_with_generate=True
)

# %%
data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)

# %% [markdown]
# # Fine Tuning the Model

# %%
trainer = Seq2SeqTrainer(
    model,
    model_args,
    train_dataset=train_dataset,
    eval_dataset=validation_dataset,
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='2109' max='2108' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2108/2108 15:01, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Bleu</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.320400</td>
#       <td>2.068144</td>
#       <td>27.014300</td>
#       <td>24.007100</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='13' max='264' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 13/264 00:16 < 05:38, 0.74 it/s]
#     </div>
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 512, 'num_beams': 4, 'bad_words_ids': [[62833]], 'forced_eos_token_id': 0}
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 512, 'num_beams': 4, 'bad_words_ids': [[62833]], 'forced_eos_token_id': 0}
# Downloading builder script:   0%|          | 0.00/2.85k [00:00<?, ?B/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 512, 'num_beams': 4, 'bad_words_ids': [[62833]], 'forced_eos_token_id': 0}
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 512, 'num_beams': 4, 'bad_words_ids': [[62833]], 'forced_eos_token_id': 0}
#     <div>
#
#       <progress value='2108' max='2108' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2108/2108 21:14, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Bleu</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.320400</td>
#       <td>2.068144</td>
#       <td>27.014300</td>
#       <td>24.007100</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.530500</td>
#       <td>1.956574</td>
#       <td>28.728800</td>
#       <td>23.788500</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=2108, training_loss=1.9815307197353644, metrics={'train_runtime': 1275.6535, 'train_samples_per_second': 26.421, 'train_steps_per_second': 1.652, 'total_flos': 738843465351168.0, 'train_loss': 1.9815307197353644, 'epoch': 2.0})

# %% [markdown]
# ## Saving the Fine Tuned Transformer

# %%
trainer.save_model("FineTunedTransformer")
# Out:
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 512, 'num_beams': 4, 'bad_words_ids': [[62833]], 'forced_eos_token_id': 0}

# %% [markdown]
# ## Perform Translation on Test Datset

# %%
test_results = trainer.predict(test_dataset)

# %%
print("Test Bleu Score: ", test_results.metrics["test_bleu"])
# Out:
# Test Bleu Score:  30.1198

# %% [markdown]
# ## Generate Prediction Sentences

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# MarianMTModel(
#   (model): MarianModel(
#     (shared): Embedding(62834, 512, padding_idx=62833)
#     (encoder): MarianEncoder(
#       (embed_tokens): Embedding(62834, 512, padding_idx=62833)
#       (embed_positions): MarianSinusoidalPositionalEmbedding(512, 512)
#       (layers): ModuleList(
#         (0-5): 6 x MarianEncoderLayer(
#           (self_attn): MarianAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): SiLU()
#           (fc1): Linear(in_features=512, out_features=2048, bias=True)
#           (fc2): Linear(in_features=2048, out_features=512, bias=True)
#           (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (decoder): MarianDecoder(
#       (embed_tokens): Embedding(62834, 512, padding_idx=62833)
#       (embed_positions): MarianSinusoidalPositionalEmbedding(512, 512)
#       (layers): ModuleList(
#         (0-5): 6 x MarianDecoderLayer(
#           (self_attn): MarianAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (activation_fn): SiLU()
#           (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): MarianAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=512, out_features=2048, bias=True)
#           (fc2): Linear(in_features=2048, out_features=512, bias=True)
#           (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (lm_head): Linear(in_features=512, out_features=62834, bias=False)
# )

# %%
predictions = []
test_input = test_dataset[TRANSLATION]

for input_text in tqdm(test_input):
    source_sentence = input_text[PORTUGUESE]
    encoded_source = tokenizer(source_sentence,
                               return_tensors='pt',
                               padding=True,
                               truncation=True)
    encoded_source.to(device)  # Move input tensor to the same device as the model

    translated = model.generate(**encoded_source)

    predictions.append([tokenizer.decode(t, skip_special_tokens=True) for t in translated][0])

# Move the model back to CPU if needed
model.to("cpu")
# Out:
# 100%|██████████| 2341/2341 [09:24<00:00,  4.15it/s]
# MarianMTModel(
#   (model): MarianModel(
#     (shared): Embedding(62834, 512, padding_idx=62833)
#     (encoder): MarianEncoder(
#       (embed_tokens): Embedding(62834, 512, padding_idx=62833)
#       (embed_positions): MarianSinusoidalPositionalEmbedding(512, 512)
#       (layers): ModuleList(
#         (0-5): 6 x MarianEncoderLayer(
#           (self_attn): MarianAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): SiLU()
#           (fc1): Linear(in_features=512, out_features=2048, bias=True)
#           (fc2): Linear(in_features=2048, out_features=512, bias=True)
#           (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (decoder): MarianDecoder(
#       (embed_tokens): Embedding(62834, 512, padding_idx=62833)
#       (embed_positions): MarianSinusoidalPositionalEmbedding(512, 512)
#       (layers): ModuleList(
#         (0-5): 6 x MarianDecoderLayer(
#           (self_attn): MarianAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (activation_fn): SiLU()
#           (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): MarianAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=512, out_features=2048, bias=True)
#           (fc2): Linear(in_features=2048, out_features=512, bias=True)
#           (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (lm_head): Linear(in_features=512, out_features=62834, bias=False)
# )

# %%
y_true_en = []
y_true_pt = []

for input_text in tqdm(test_input):
    y_true_pt.append(input_text[PORTUGUESE])
    y_true_en.append(input_text[ENGLISH])
# Out:
# 100%|██████████| 2341/2341 [00:00<00:00, 663526.53it/s]

# %%
output_df = pd.DataFrame({"y_true_port": y_true_pt, "y_true_eng": y_true_en, "predicted_text": predictions})
output_df
# Out:
#                                             y_true_port  \
# 0                                             هل ستغني؟
# 1                           لماذا لايحب الالمان اليهود؟
# 2                                          يا لسوء حظي.
# 3                                          البحث الجديد
# 4            السرير الذي نمت عليه بالأمس لم يكن مريحاً.
# ...                                                 ...
# 2336      وغرد فرشد فاريابي عن زيارة وزير خارجية السويد
# 2337  أنا مازلت أحاول ان أعزف على الجيتار مثل إريك ك...
# 2338  العديد من المواطنين يدونون ويرسلون رسايل تويتر...
# 2339  وبالرغم من ان الحكومة السابقة منحت تراخيص لشرك...
# 2340  هذه نسخة من صحيفة تشرين التي يعود تاريخها الى ...
#
#                                              y_true_eng  \
# 0                                Are you going to sing?
# 1                     why didn t germans like the jews.
# 2                                     How unlucky I am!
# 3                                         new research.
# 4     The bed I slept in last night wasn't very comf...
# ...                                                 ...
# 2336                           farshad faryabi tweeted.
# 2337  I'm still trying to play guitar like Eric Clap...
# 2338  many citizens are blogging and tweeting about ...
# 2339  the previous government however granted licens...
# 2340  anasonline this is a copy of tishreen newspape...
#
#                                          predicted_text
# 0                                        Will you sing?
# 1                          why don t germans like jews.
# 2                                 How unfortunate I am.
# 3                                         new research.
# 4     The bed you slept in yesterday was uncomfortable.
# ...                                                 ...
# 2336  frahd farabi tweeted about the swedish foreign...
# 2337  I'm still trying to play the guitar like eric ...
# 2338  many citizens blog and send twitter messages a...
# 2339  although the previous government has granted l...
# 2340  here is a copy of the year old newspaper turks...
#
# [2341 rows x 3 columns]

# %% [markdown]
# ## Loading the stored Model and using it for translation

# %%
ft_model_tokenizer = AutoTokenizer.from_pretrained("FineTunedTransformer")
ft_model = AutoModelForSeq2SeqLM.from_pretrained("FineTunedTransformer")

# %%
ft_prediction = []

for sentence in tqdm(x_test):
    encoded_text = ft_model_tokenizer(sentence, return_tensors='pt', padding=True, truncation=True)
    translated = ft_model.generate(**encoded_text)
    ft_prediction.append([tokenizer.decode(t, skip_special_tokens=True) for t in translated][0])
# Out:
# 100%|██████████| 2341/2341 [48:13<00:00,  1.24s/it]

# %%
ft_prediction
# Out:
# ['Will you sing?',
#  'why don t germans like jews.',
#  'How unfortunate I am.',
#  'new research.',
#  'The bed you slept in yesterday was uncomfortable.',
#  'My goal is to be a doctor.',
#  'lebanon a wedding global voices.',
#  'You disappointed me in you.',
#  "Let's ask her when she gets home.",
#  'the decision has been made in the last few minutes.',
#  'I have only one brother.',
#  'this is just a quick glimpse of the situation in lebanon without the presidency next week we will have more.',
#  'instead of grapes world yasu haley silassi makes wine from khat paper a subject that people chew widely in east africa and the middle east for drug effects.',
#  "There's one apple on the desk.",
#  'how to enjoy traffic global voices.',
#  'united states and uae have set up a clothing center to counter ismas s online propaganda.',
#  "Take care of what you're saying, Tom.",
#  'the global voices citizen media summit is open for registration.',
#  'trinidad tobago voting process global voices.',
#  'How can you not say anything?',
#  'india brain drain from the united states global voices.',
#  'muslims have a huge share of their consumers to say pakistani or people who love ester.',
#  'Tom came at the last moment.',
#  'we urge the bahraini government to release hassan and we invite international ngos foreign governments and other powerful entities to join us in calling for mohamed hassan s freedom.',
#  'photos from fashion week in pakistan global voices.',
#  'on facebook urgent tv fired broadcaster mesa saleh for being impressed by his criticism of the owner of the channel.',
#  'nothing against serbia writes about the building built by braneslav kujic in which is considered one of the most successful examples of modernity in belgrade.',
#  'kyrgyzstan radiation train global voices.',
#  'national day for internet freedom march photo shared by pri org.',
#  'She finished reading the letter.',
#  'dream tv repeats the terrible israeli invasion of lebanon in more about it here.',
#  'screen shot from youtube video.',
#  "I'm just looking, thank you.",
#  'news of the collapsing buildings and the withdrawal of the body of the children from the wreckage is too many in egypt blogger ibn al dumiya from the qatar blog writes about the latest tragedy that killed five innocent victims.',
#  'afghan writer abbasad buda wrote.',
#  'Tom invited Mary to dinner.',
#  'Are you at home?',
#  'Close the gate.',
#  'the government can be forgiven for one mistake but it has become unforgivable when it has become a heritage i m not a national but years of history have proven that russia and china have never done anything right by supporting each other.',
#  'palestinian journalist dima al khaibab also wrote a piece on her blog love not hate my dear mona.',
#  'why don t indians swim in the sea.',
#  "Are you sure you haven't forgotten anything?",
#  "Don't you love me anymore?",
#  'When did you start playing golf?',
#  'ahmed valsafi died about years ago ahmed was a dentist and blogger who writes on his blog about years ago many consider him the sheikh of iranian bloggers.',
#  'the police didn t comment on the recording after the arrest but most of youtube users claimed their support for the man s work.',
#  'a group of israeli independent musicians gather together to create a song called the sons of freedom as a expression of their support for the new freedom of the egyptian people and to elect new neighbours human rights and equality in both countries.',
#  'Most students come to school on foot.',
#  'the judge was about to verify the plea bargains on february but most likely his death will delay.',
#  'The popularity of websites depends on their content.',
#  'property rights.',
#  "It's not the ultimate goal, but it's the process to get there that matters.",
#  'due to fear of the long term health effects of nuclear power generation fukushima daiichi some indigenous japanese people decided to move with their families to states or other countries the actual numbers have not yet become clear with the existence of numerous reasons for these self determinations but the nature of these moves is different from the evictions that took place during the weeks following the beginning of the disaster.',
#  'netizens on twitter can report violations update and tweets users of this hashtag and means elections in bulgarian.',
#  'the bobs contest nominated your favorite blogs and best characters on microblogging pages global voices.',
#  'Can anyone help me? "I will."',
#  'ethiopia outraged at the abuse of an ethiopian domestic worker in lebanon global voices.',
#  'the bb in tweet writes that a kurdish parliamentary deputy has been arrested amid clashes between turkish riot police and kurds wishing to celebrate newroz day.',
#  'Who owns this elephant?',
#  'This is yours.',
#  'Come here is the capital of canada.',
#  'many were insulted by his words including smir yezbek a pro revolutionary writer who asked yizbek didn t shut up after it became clear that one of the alleged soldiers was from the year ago a response that seemed to try to make the point but apparently it wasn t her aggression.',
#  "People go ahead. We'll follow you.",
#  'honduras relations with taiwan global voices.',
#  'on this occasion we receive presents if you like to support our work we ask you to consider donation to us or buy some of the christmas tickets designed on the u s national security agency created by our friends in a publishing house and returned to us entirely.',
#  'nobody denies that hepatitis has become a health issue in tanzania the world health organization s hepatitis day report has ranked the country in among other countries where hepatitis is high and accounts for percent of the global disease burden.',
#  'I like Japanese very much.',
#  'marzoug says.',
#  'the komaba band with venezuelan artist chiu ortado photo from the facebook page loves the komaba band in venezuela used with permission.',
#  'iraq hospitals are improving global voices.',
#  'May I go out to play?',
#  'and these are the steps as explained.',
#  'She killed herself.',
#  "She can't express her deep sorrow.",
#  'nm i understand that one of the goals of your project is for africans to start talking and telling each other there is a country in africa that uses different languages how will you overcome language barriers since the current content is in english.',
#  'I thought you might feel sorry for Tom.',
#  'She brought me a glass of tea.',
#  'today the world met with videos of the syrian demonstrations many thought it would never happen especially after a similar invitation failed in february to convince syrians to take to the streets the next video was taken in hama where the syrian army committed a massacre in a muslim brotherhood uprising you can hear the protesters chanting freedom and sacrifice our joys and blood for daraa.',
#  'south korea seoul july.',
#  "It's the right decision.",
#  'many internet users despite their obedience to the court s ruling were wondering why the court s ruling had been issued so long the journalist hu ji hyun quickly compared the arrest of pastor joo who was accused of spreading false rumors about elected president pak kun hee the journalist wrote.',
#  'this has raised the concerns of both factions mor and mor and therefore samir jaa who belongs to the emer nominating group michel aoun who belongs to the eorn regime to reach the presidency in january both alliances have formed a united contrast in the face of the beirut movement my city to ensure the victory of the elections and indeed this move took its toll and the loss of beirut movement became somewhat possible according to the system of majority of the winning parties with all the seats this changed in the summer of but it was too late for the beirut movement my city.',
#  "I'll eat it here.",
#  "I'm in love with another man.",
#  'palestine israel end of conflict global voices.',
#  'surveillance tool to track insecticide resistance insecticide vectors global voices.',
#  'He always treats me as a child.',
#  'Where did you meet Tom?',
#  'many activists journalists and ordinary citizens around the world are using two step verification technology see below on social media and e mail services to achieve a new level of security for their communications but it seems that government actors may exploit this advantage for their own gain at the moment.',
#  'I thought you said Tom was dead.',
#  'I want to go to Tokyo.',
#  'jonaar almeida expressed his irony at the news of the death of the architect.',
#  'it is not an isolated event.',
#  'he prefers wael a respectable and i m not saying he is disrespectful but his priorities aren t ours i m not aware he is not aware of the situation nor any of it.',
#  'this post is part of a special series of articles by blogger and activist marcell shehwaro describing the realities of life in syria under armed conflict between the regular forces and the free army commanders.',
#  'photo by ellery biddle and reem al masry at the internet governance forum photo by hisham almira used with permission.',
#  'i live in mount hossein a very crowded place which has made me leave my job as it was minutes away from my house and i can t find anyone to accept my ride.',
#  'as many of our readers know the arab bloggers meeting has been an important space and platform for our society since the first meeting took place in beirut in the recipients gathered voices from around the arab world and played an important role in helping digital activists build a solidarity network ahead of the arab uprisings.',
#  'iraqi highlights the issue of the new iraqi flag.',
#  'the english island is doing the work it makes it clear that the arab island is not willing to do.',
#  "I think it's a lot better now.",
#  'new railways will sit on the debt of trillion yuan billion billion which will lead to higher ticket prices reformist reformists price hikes in favor of reform price hikes like health reforms education reforms and housing reforms will be dismantled by the railway ministry just like others.',
#  'I wrote three letters last night.',
#  'the latest goals of egypt s censorship campaign blocked human rights and blogger global voices.',
#  "I'm going to get down at the next station.",
#  'Can I come again?',
#  'only those who understand the language of history can understand shakila shakila s language it is an expression of all those whose killers have not known they are criminals.',
#  'No food is available for those who do not work.',
#  'No one encouraged her.',
#  "He will go to Tokyo tomorrow, won't he?",
#  'i can only comment a little bit on this beautiful hashtag by my mexican loved ones on twitter thank you for that spirit thank you for your support i love you.',
#  "I'll eat it here.",
#  'another twitter user said.',
#  'We arrived at the office in time.',
#  'We went to the same church.',
#  'earlier this week a fire broke out in a workers camp in doha qatar and destroyed the property of approximately workers in the workers camps in the gulf states it is usually in the form of major shelters with separate gender rooms where hundreds of migrant workers earn about dollars a month the golf times published the story and details of the destructive effects of the fire on workers within hours of the story being republished on the internet forum by the user called on all users of a forum to donate to workers in need where he launched a call to users.',
#  'photo by flickr user flickr.',
#  'ukrainian photographer maxim donduk documents tuberculosis in ukraine every day a person dies each year and kills more than the same you can see the dramatic images of the tuberculosis on his blog tumblr ru on his website and in english there is a dondok business fair on september in moscow ru at andre khaarov museum.',
#  "I'll pick you up after work.",
#  'last but not least designer vikki explains her shirt saying the design reflects the four elements students red book death and june.',
#  'hossein ronghai maleki and his mother zelika are on hunger strike now photo from the campaign s facebook page.',
#  'you don t have to post anti society material online in the top image please come with me because you have published articles insulting the nation unit in the lower photo by elisabeth dalzil ab via.',
#  'I want to introduce you to some of my friends.',
#  'Did you snow yesterday?',
#  'scientific knowledge has increased thanks to the ongoing work of thousands of researchers around the world we know more than we used to in the context of climate change its potential consequences in the future and what we have to do to avoid the most damaging effects.',
#  'the blog all links es showcases the fans of song discovering music from around the world with a focus on latin america the blog contains special dialects for songs such as come songs according to the country songs according to posters and songs recommended by readers the last category contains a post about songs you recommend during an interview in the elevator.',
#  'in addition to the un agenda bolivia s three strategic focus is on the coca or cocaine problem increasing foreign investment in gas exports to brazil and argentina to increase the quality of liquefied gas and thus gas subsidies and coastal control in the pacific where bolivia has so far failed at these three points.',
#  'He would have told me the truth if I had asked him.',
#  'Tom sold his house.',
#  'the issue of greenhouse gas which was an important topic this time was discussed by the gb on the second day mr fukuda hoped to set a long term target for a decrease by but the us said the debate was absent from the most produced countries china india brazil etc it seems that he could not get us permission to discuss the issue and that is very clear i think.',
#  'live broadcast.',
#  'forms of restriction and coercion before campaigning begins.',
#  'philippines education index global voices.',
#  'donate to a safe world to support a school in the zaatari refugee camp the children s camp is called because almost half of its population is under the age of.',
#  'although political tension between the united states and iran the iranian cheetah project a collaborative effort of the united states based wildlife conservation community and iran based environmental ministry is studying and rescuing the asian cheetah also referred to as iran s cheetah and yuz palang balang al farsi it remains in the world of only about these cheetahs and its only home is the sahrian abran plateau.',
#  'The heavy winds were blowing.',
#  'Tom and I depend on each other.',
#  'instagram users shooting the fog in khabarovsk global voices.',
#  'the sun shines to show the sad owners jumping to fish while women fall on the roof with long wood boats the marshes extend by an estimated area of square miles into the middle of the desert some scholars of ancient history believe that the marshes full of fishes and birds are the same as those mentioned in the torah.',
#  'Call me.',
#  'When will you die?',
#  'youth workshop in sarayaku photo by abigil gualinga.',
#  'queen rania the first youtube prize has been awarded to novelians for her persistent incentive to young people to confront misconceptions about the islamic world we are always impressed by her persistent vision and leadership.',
#  "Hurry up, or we'll miss the train.",
#  'He paid no attention to my advice.',
#  'jason sun one of the supporters of the province has launched an open forum on.',
#  'the stories of students with unemployment are many but others face additional challenges like disabilities.',
#  'fas that solomon makes it more difficult because the physical recognition of work is not done with the same financial value as white holocaust production we always work with budgets that are way lower than that of production directed white photography.',
#  'many areas have been blocked by security guards to prevent passers by and to stop more protesters from progress.',
#  'She bought a game for her child.',
#  'croatia s website reviews some old and modern wish and some problems related to croatia s plans to join the european union on july.',
#  'the official logo of africa what is your story.',
#  'I just want an honest answer.',
#  'no one in indonesia is sure what motivates criminals to kidnap children to serve their purposes what is clear is that this trend is growing and growing amid the climax in this criminal wave of kidnapping the release of ricia a year old girl who is still in kindergarten yesterday afternoon after being kidnapped for days in kharia.',
#  "Tom told me he doesn't remember the professor's name.",
#  'hani bahaid from jordan asked can someone add a facebook show called a sexy young man on the same day join a group called proud muslim.',
#  'I met him on several occasions.',
#  'These are birds.',
#  'jillian york from the eff foundation published a short post on the state of digital rights in the arab world.',
#  'iran fake person running for the upcoming elections global voices.',
#  'laughter is now legally healthy in hospitals in buenos aires argentina.',
#  'why don t japanese people grow old.',
#  'micro image of sund cloud by flickr user jonas bangitsun cc by nc sa.',
#  'This knife is too sharp.',
#  'hollaback proposes several ways to join it in english the movement in the united states established its presence in several american cities but hollaback has local web sites already created by women in cities such as london mumbai and pinos aires and in countries like chic and france.',
#  'I warned you not to come here.',
#  'My father helped me with my homework.',
#  'lebanon new karem lib nwai video global voices.',
#  'follow our in depth coverage gaza civilian death toll mounts.',
#  'Congratulations.',
#  'for her part the constitution and citizen blog drew attention to a unesco campaign called no more anti personnel mines that every hour mines receive a new victims in colombia.',
#  'palestine art resistance global voices.',
#  'You have six unread messages.',
#  'on september jeju congerus hosts global protection which is ridiculous in light of what is happening in gangjyong now we must inform the organizers of the event and news agencies about this tunnel please email the organizers and alert the media we need to draw the attention of many people and by any means possible to the atrocities occurring in gangjong.',
#  'angon room or an organized engine room that works to research and support the best use of defense technology its mission is to strengthen and update existing support networks for a safe and effective spread of new defense technologies.',
#  'This is a yellow flower.',
#  'We need to do important things first.',
#  "The judge's decision is a separate one.",
#  'yasmine bouchin algeria december photo ophelia noor used with permission.',
#  'bloggers have resisted the law and posted an advertising video on their websites saying i don t register my blogs later the government realized that it is unable to find real control or force bloggers to register.',
#  'i was born in the middle of a frankovonian family in lebanon and paris has always considered my second home the streets of paris are like the streets of beirut for me and in fact i was in paris a few days ago.',
#  "I'll buy that.",
#  'or the effects of a scarf.',
#  "Swimming well, isn't it?",
#  'this event was organized by two bloggers most of the questions were read by iranian bloggers hanif manzouri and somayeh tohideloz internet users like twitter facebook e mail and yahoo masnagar to voice their questions and reactions to a khatami interview can be found on fredefield.',
#  'His son was fired from school.',
#  'I guarantee this information is correct.',
#  'why don t iranians wear tie.',
#  "I'd be glad to help you.",
#  'durban second conference how and who.',
#  'the muslim bloggers association has published two slogans fa in support of palestinians in the gaza strip in one of the slogans gaza is the land of resistance blood and weapons.',
#  'malek lost his left eye job working for him to save his eye shape and location.',
#  'our five internet citizens s choices were pgb encryption anti virus software updates and android virtual personal networks and the ability to host websites outside iran.',
#  'tomorrow let s all head to the university to support our friends and teachers in their strike.',
#  'I did this by myself.',
#  'I have to talk to her about the new plan.',
#  'Maybe Tom has something to hide.',
#  'syrian maria enthusiasts her with another story about history love and human relations shared by ali arabia this is part of the first.',
#  'sofia past present photo courtesy of alexander nikolov used with permission.',
#  'syrian spirits lost.',
#  'art is open to people to denounce or talk about the violent events they have experienced and the art is a form of resistance this is what jorge teliz tells us in his post lyrics about violence in a blog where he mentions some initiatives that draw reality through poetry and photography.',
#  'cho claimed that ruh s secret accounts disclosed his suicide and said he got the information from a secret source and has not established the claims so far many consider that the allegations are without basis a district court in downtown sol former police chief cho defamatoryly defamatoryd the deceased former president and jailed him on february.',
#  'karimov a singer and perfumemaker named princess was one of the few known public figures outside her home and international investigators are investigating her involvement in one of the cases of corruption with telecom companies that managed to contract in uzbekistan.',
#  'the chinese translation of this temple from the th century is the monarchy and refers to the worth of king mendon due to his donation of nearly rockboards with translations from tribataca buddhist sacred texts this temple is famous today as the world s largest book located in mandalay the capital built by myanmar s last ruling strain.',
#  'although i don t agree with her tone i definitely don t agree with the images used but there are some facts in the mona eltahawy article we can t afford to ignore them anymore.',
#  'She ran into an old lady.',
#  'egypt university faculty strike global voices.',
#  'How much longer are you back!',
#  'Tourists often buy souvenirs from this shop.',
#  'the irony of nazar ahari s story is that she can feel lucky to have spent four years in jail after being cleared of a war on god s behalf which is a crime that could result in death penalty.',
#  "What's your job?",
#  'i demand the withdrawal of russian occupying forces from georgia dmitry anatulovic.',
#  'I must buy one.',
#  'the film revolves around individual discovery and identity research based on the common concepts that prevailed during the era of incas in the andes as well as the traditions of the grandparents who lived in this region seeking the best way to understand the nature of things the text was presented on the official film website as well as the locations of the film which made it possible to do the work according to the statement of the participating representatives there is no text for the film and has been hired by social media and technology to introduce the project and its message.',
#  'Tom plays cards with Mary.',
#  'Please help me clean the house.',
#  'The rain lasted a week.',
#  'Who owns this piece of land?',
#  "It's been years since Sunday morning.",
#  'there is reason for me to accept participation in the program which is the integration of this proposed research project with a wide ranging political tv which drives the documentary that shows the violations of tv networks and the risks of reality tv.',
#  'I was busy.',
#  'in connection with the meeting al jazeera arab bloggers wrote that the arab spring has become universal and included a mention of the meeting on blogs in english by jillian york on day one where there is a round table of tunisian bloggers who have now entered politics in tunisia in different ways the big event was created by the president of the tunisian internet agency when it proved that tunisia had been secretly experimenting with the internet censorship tools created by western companies.',
#  'human rights watch called for the immediate release of saudi american citizen mohammed salam in prison for tweets critical of the continent.',
#  'and with her so far she is following the update of only one person the region s reactions began to show off on the queen s microblogs adventure.',
#  'thousands of protesters against war with syria in istanbul photo shared on twitter.',
#  'how japanese people hang out to dry global voices.',
#  'but the ability to engage in deep dialogue reading literature the valuables of swimming watching the beauty of nature crisp and acting in the performances are all expressions that give meaning to his life and make him feel like a acquaintance don t forget to enjoy your day al halabi said this is more important than this post anyway.',
#  'He gave his blood to help his sister.',
#  'egypt s parliament is reviewing a draft bill that asks social media users in egypt to register with the government to allow them to use social media sites including facebook and twitter.',
#  'a group of tourists enter the village market in fermoly bangladesh mozym mostakim used with permission.',
#  'The spring will come soon.',
#  'kuwait christmas global voices.',
#  "Don't worry. I'll take care of you.",
#  'faces of participants protesting no muslim ban at lafayette park in washington january photos ivan sigal.',
#  'She promised not to be late again.',
#  'Do you like apples?',
#  'there are no enable points.',
#  'Tom tried not to look at Mary.',
#  'May I have a piece of that cake?',
#  'They did an experiment to see if the medicine improved memory.',
#  'The only thing standing in this world is change.',
#  'Tom wants to go to Australia.',
#  'mural in tribute to writer ugusto roa bastos photo cc by nc sa.',
#  'follow the summit news on our website facebook and twitter updates.',
#  'Why did you see a doctor?',
#  'i filmed a mall from onagawa hospital climbing a cliff from onagawa school to marinbal road as i walk i found a lot of live fish on the road.',
#  'I met him on the road that day.',
#  "What's new?",
#  'The conference will be over tomorrow.',
#  'and please accept my dear dear regards and respect.',
#  'gv what kind of work has your organization done so far on domestic violence in armenia.',
#  'Let me sleep another ten minutes.',
#  'Japan is an industrial country.',
#  'the list includes human rights defenders journalists writers researchers feminist movements and artists as well as numerous individual and collective blogs and facebook pages that strive for gender equality and the fight against racism and discrimination in brazil.',
#  'We might need some.',
#  'I know him.',
#  'i loved the beirut spring initiative very much.',
#  'lc do you think the economic crisis has changed the law if yes how did it happen.',
#  "You'd better leave. It's late.",
#  'She is married to a seaman.',
#  'no not the king is here but the king is in belgium.',
#  'you can read more about fake news and french elections in this link.',
#  'Go back to your seats.',
#  'I have a test tomorrow.',
#  'Is that place far from the bank?',
#  "I'm not well.",
#  'iranians turned to the polls held on may to cast their votes in the national and local presidential elections there was a woman with a total of percent of all candidates out of candidates registered to run for iran s national and local elections the women s vote became significant both locally and at national level hassan rouhani was re elected as president elected from the middle category amid the increase in the number of women candidates as well as other women elected.',
#  'before the ruling american destroyers patrolling the disputed waters as part of what the united states officially described as the natural presence of the us navy in the region.',
#  "I can't thank you enough for all your kindness.",
#  'You must help your mother.',
#  'I made you breakfast.',
#  "He is the last person to ask for help he is someone you can't depend on.",
#  'morocco bloggers in mourning for free speech global voices.',
#  'on december egypt blocked the free basics of facebook app on the mobile phone while many reacted quickly to focus on censorship as an act of censorship several reports pointed out that the censorship was due to facebook s refusal to allow the egyptian government to spy on users of the app.',
#  'The doctor told me I must drink more water.',
#  'algeria election observed by internet activists global voices.',
#  'How old are you? "sixteen."',
#  "You're straining yourself with work.",
#  'the world privacy community lost two of the strongest defenders in the past two weeks kasper bauden died on july who fought for the right to privacy in a global context for all and then on dr uzgur ushkan a co founder of the olterniev movement belgium digital rights.',
#  'Every horse has a cube.',
#  'for more information or interviews please contact the global voices advocacy advocacy director bahtam almiri biddle global voices advocacy editor on email.',
#  'Any boy can do that.',
#  'His win made him a hero.',
#  'arab bloggers meeting we have to stop thinking technology will solve all our problems global voices.',
#  'in a flash of good news the bbc list included the most influential woman blogger razan ghazzawi.',
#  'joel from the blog translates several posts that have analyzed the effectiveness of traffic controls in beijing to improve the environmental condition of the city.',
#  'kocheck has also given us more updates on repeated bloggers initiatives.',
#  'saudi arabia rear gate for women global voices.',
#  'Mary is my wife.',
#  "If you don't work, you can't eat.",
#  'My mother is angry.',
#  'She bought eggs in aldarzen.',
#  "I'm confused by his presence.",
#  'bahrain the birth of a maldi imam global voices.',
#  'all authorities at the three levels of government are calling on the government to investigate the killing of salvador adame and solve the case.',
#  'join us in adopting these rights and publishing them in your neighborhoods villages and cities talk to us in order to develop this document for the better if you agree with us on the rights raised in this document and the importance of being covered by the new egyptian constitution sign this document and share with us the collection of signatures from different regions of egypt so that they become a common demand for all of us.',
#  'ramy raoof started an egyptian blog on human rights the blog follows the evolution of human rights especially in egypt as well as the arab world in general.',
#  'saudi arabia.',
#  'israel palestine and kosovo global voices.',
#  'She asked me to wake her at six.',
#  'two versions of mao chinese era distort history for reasons of propaganda global voices.',
#  "Let's go home.",
#  'saudi arabia saudi prince calls for political reform global voices.',
#  'Shut up!',
#  'egypt lab kills an officer global voices.',
#  'these short films of young people in cambodia seek to end sexual harassment global voices.',
#  'bolivar played a major part in the liberation of five countries in latin america bolivia colombia ecuador peru and venezuela and was considered a universal historical character in the beginning free venezuela colombia then ecuador to a large state called the great colombia then went to peru to ensure the defeat of the spanish forces.',
#  'Please think about it.',
#  'we thought it would be just a photograph of us khashan told but we were shocked when we watched the calendar on the internet with these stupid phrases i explained to my close friends on facebook what happened because the reaction in syria was terrible everyone was angry with these phrases.',
#  'aside from a number of bloggers warning that mehdi khazali s life is in danger there are also a number of them questioning that he is on hunger strike.',
#  'frankonofia visited mount athos in greece on october where he met with the new president of the russian orthodox church of monks.',
#  'Stop teasing your sister!',
#  'some groups claim that there was a western conspiracy to dismantle the unity of yugoslavia while others blame bad governance by the political elite but regardless of the crisis yugoslavian leaders had a historic opportunity to exploit the year old stability of the state to promote national unity across ethnic groups but instead serb rulers sought to promote the commercial and industrial excellence of serb serb serb serb serbian politicians and intellectuals sought to promote serbian dominance with the regime at that time the result was a civil war in bosnia.',
#  'Who owns this house?',
#  'Tom arrived at about 2:30.',
#  'it will be a year to dig for oil and gas in lebanon according to the timeline to be approved by the cabinet as published by spring lebanon.',
#  'finland s california july.',
#  'Football is my favorite game.',
#  'on the other hand what turns you on as a journalist.',
#  'Because of global warming, cities could be completely flooded.',
#  'translate the title of the story is haruki murakami going to win the nobel prize the nobel prize for literature award is scheduled to be announced tonight a screenshot of a video posted on the official youtube page of a station.',
#  "I'm a man.",
#  'the leaked documents on early august were confirmed by anonymous twitter accounts for claims that the bahraini government is using the spyware developed by al jama international a german surveillance company to monitor activists and politicians according to the same documents the bahraini government spyed on two members of the special truth commission that was set up to investigate human rights violations.',
#  'as the fundraising campaign kicks off for the holiday season this year we are presenting this post which shows how many people have joined together to make global voices unique.',
#  'china spying on wechat global voices.',
#  "I think that's what happened.",
#  'he sings really well if he hadn t been president he would have been a bob star or he would be a christian at weddings.',
#  'nikahang iranian leading cartoonist and blogger says fa.',
#  'fotha is looking for ideas to encourage blogging.',
#  'grandfather wen s nightmare caricature by hixi farem used with permission.',
#  'winners will be announced at the international stage of the wiki loves earth competition on september.',
#  "I know what you're trying to do.",
#  'leave mr dendias.',
#  "If there's nothing you can do, why don't you read a book?",
#  'May I ride this horse a little?',
#  'My life has changed dramatically.',
#  'venezuelan collage in solidarity with her on the virtual stage following a controversial july referendum called by president nicolas maduro for the appointment of the constitutional assembly four months after the ongoing protests against the government for its escalation of the social economic and political crisis an anonymous group of young people in mexico launched the hashtag from ariba taco with you on her twitter account twitter twitter report the cause of the initiative was reported by one of the creators of the initiative.',
#  'You are not Japanese.',
#  'morocco obama and religion global voices.',
#  'i may have the time to blog but i prefer to just sit down and stare at my daughter and inhale her smell the wonderful smell of children and think of god s favourites as our creation.',
#  'belgium campaign to stop texting while driving global voices.',
#  'the basic description of a computer is.',
#  'in some countries of latin america guagua means bus while in others it means baby the word transhumante is for travelers.',
#  'over the past month for the purpose of writing for the popular news site dnis gavorilov interviewed several uber drivers in russia to learn about their work and customs and of course their client ront aco translated the text into english and published it here.',
#  'marco singo also mentioned other surprising deaths of important athletes in the past several years.',
#  'the arab forum on internet governance will take place in beirut from november.',
#  'in this month s report most of the research editing and writing efforts were carried out by fellow users rayna st jillian c york and daniel keel.',
#  'I disagree with you.',
#  "I'll be back.",
#  'basar issued an open letter from gay iranian students to the cabbage of the country s student activists.',
#  'They are not farmers.',
#  'What would you do if you were ten years younger?',
#  'avaz stop the torture of syrian children.',
#  "I'm thinking of you.",
#  'Stay thin.',
#  'in other words this conflict is still far from coming to the conclusion of journalist yen tavaris s blogs on brazil de fatto.',
#  'Can you keep a secret?',
#  'fantastic results achieved by this russian website using neural networks to integrate images global voices.',
#  'china sex harassment at a chinese wedding global voices.',
#  'shan added a video to a video depicting the sexual harassment of women in public spaces by men either by word or by deed.',
#  'It was an extraordinary job.',
#  'No one answered the telephone.',
#  'My brother can drive a car.',
#  'privacy.',
#  "There's a little apple on the tree, isn't there?",
#  'the ongoing crisis that has emerged since has created a chronic shortage of basic goods and services such as paper electricity and broadband internet services creating a tense and restrictive perspective on communications and information sharing in a political effort to curb public access to information and news.',
#  'The ship was at the mercy of the waves.',
#  'Will you be in the country at christmas time?',
#  'pokemon go has become a global phenomenon with more than million downloads since its release on july in some countries.',
#  'it appears that the netizens who watched the video loved his singing style frida salmanova commented.',
#  'a digitization software has been launched for years and a pen it s been said to be a loser the file has also been announced for years and we still keep on promise kmon let alone that the web is completely absent in the official administrations.',
#  'a photo of the user s twitter account posted on pri org.',
#  'I may have forgotten the umbrella on the bus.',
#  'it also seems that the way to hang cotton dolls to dry after washing is one of the biggest challenges.',
#  'c custer from tichenafi told the end of his post.',
#  'mambo ravi yangu.',
#  'since the early days of the syrian revolution the syrian regime has praised the state of military action and made it a romantic and passionate idea on the entrance to the coastal province of latakia muscat ras the dictator of syria has set a statue of military shoes full of flowers to be the first to fall inside our eyes to the province several similar military shoes have been deployed in the areas controlled by the regime.',
#  'Did you play tennis yesterday?',
#  'you can find out more about ono via facebook and twitter user name and see more about internet security visit tactical technology.',
#  'she expresses her anger at a mixed story where lebanese are married to israeli and given her lebanese citizenship while lebanese women are still unable to grant citizenship to their husbands whatever their nationality.',
#  "Let's take a look.",
#  "I didn't get a choice.",
#  'syrian government media have been careful to upload photos of the flooded emotional flow towards the regime s army as prominent figures appear along with ordinary citizens who all kiss military shoes magnify as loyal and grateful.',
#  'and that s not all there is a debate that is getting further into the background of a fan page created by an egyptian blogger for queen rania ali facebook.',
#  "I'm going to need some more time.",
#  'if someone steals a scientific message he is usually punished or blamed especially if he copys her research but who steals an advertising campaign without blushing his face what is her punishment in that case should he return the money she receives from the declared company or give him a moral warning from his peers abroad.',
#  'learn about the initiative and watch the first part here.',
#  'How are we going to pay our debts now?',
#  'this group described facebook s efforts to curb rising calls against the rohinga people as a counter to active regulation and referred to the company s conservativeness of involving local contributors in finding systemic solutions as well as a lack of transparency.',
#  'She pretended to be sick.',
#  'source uranium this material has to be handled and is covered with lead canisters this is dangerous.',
#  'in order not to remain ambitious the initiative requires active commitments by participating companies to ensure a high level of care for companies as well as risk management in relation to the demands they receive from the government greater transparency for users about the impact of these demands on free speech and privacy in all facilities where they are used the company will be evaluated with an independent and impartial accountability process.',
#  'reza says your open eyes have taught me a lesson don t close your eyes to injustice.',
#  'He looked at the sky.',
#  'She agreed to marry him.',
#  'the same scene is frequent in panias and these are some of the footage he uploaded on youtube about the popular fever.',
#  'Where is the cream?',
#  'the southeast asia digital library is home to educated users and students with materials published in southeast asia the online library contains digital versions of books and manuscripts as well as visual materials and catharsis which are searchable for additional sources such as southeast asia.',
#  "I don't want to lose you.",
#  'The swans can accommodate a lot of fish in their bed.',
#  'the page continues to describe the facade.',
#  'I feel sick.',
#  'zambia donates five million liters of fuel to malawi global voices.',
#  'i feel bad why do they come to me they think i am a terrorist but lababidi adds he understands that the police were only doing their work.',
#  'I like the sound of change during his fall on the roof.',
#  'I expect your help.',
#  'lebanon questions about expats global voices.',
#  'I gave up smoking a year ago.',
#  "You're there! Please wait.",
#  'cuba a community without trees global voices.',
#  'algerian blogger marzoug touati may be in jail for an interview with israeli official on youtube global voices.',
#  'Who are you talking about?',
#  'indian muslim writes about a world heritage site in danger of losing recognition because of religious clashes.',
#  "Tom's next murder will be the last.",
#  'fiona harvey is a leading environmental journalist for the algerian newspaper award i ve worked for the financial times for more than a decade and has reported on every major environmental issue from far away areas such as the arctic and amazon and has a wide range of interviews including ban ki moon tony blair al goor and jeff emmelt tweets to me.',
#  "I promise, I'll never do it again.",
#  'israel digital arabs jews in a delicate balance global voices.',
#  "I'm very hungry.",
#  'Do you know my father?',
#  'i think it is necessary to honor one of the main corners of brazil which unfortunately continues to suffer from bias and discrimination i think the audience can understand this idea we heard about a science professor talk about this and show our artwork to their students and brazilians living abroad wishing to showcase this aspect of our culture to others there is great interest whether it is a practice of african religions or not.',
#  'as the global battle for the future of the internet raged more than organizations including the pro press freedom and freedom group the new american foundation the open access institute and the electronic frontier foundation announced the declaration of internet freedom statement on july the declaration confirms five fundamental principles of internet freedom free speech openness innovation and privacy.',
#  "It's a late hour.",
#  'Which one do you prefer meat or fish?',
#  'cagb i think i m a mix of all of it i don t think i can t see myself a teacher who is unable to act effectively and think critic or a writer who is chained in front of his computer and simply recounts or writes poems about them without living on the ground as you can see all these actions are closely related to words in other words i think i love words that are felt and translates into actions if you don t seek to make a difference from your words you better stay silent.',
#  'speakers who have kindly shared their experiences during the summit sessions can watch the reports and videos on the summit website.',
#  'islam karimov president of uzbekistan went to the hospital for treatment this news is definitely false president khaled.',
#  'russian federal censorship of the judicial appeal indicates that linkedd collects and passes data on russian citizens including those who are not members of the website violating several privacy laws the court ruled on august in favor of the government and asked the police to take action to restrict the use of linkedin across the country.',
#  'That was hard to believe.',
#  "I'm listening to the radio.",
#  'He looks young.',
#  'the breaking borders award is a new award made by google and global voices with support from tomson reuters to honor outstanding online projects carried out by individuals or groups whose work is brave and active in their quest to use the internet to promote freedom of expression and the deadline for applications is february please send us your nominations soon.',
#  "I'd rather starve than steal.",
#  "I'm at home.",
#  'The little man began to cry all night.',
#  'marzoug from a blog describes the weather as crazy and explains it.',
#  'the mere defense of political opponents in tajikistan could cause you a lot of trouble.',
#  'waiting for results.',
#  'only arabs and terrorists a live blogger from occupied palestine opens his story pointing out the news that emerged in israeli and western newspapers after hossam taseer dwayat a palestinian living in jerusalem led by a bulldozer in a crowded street in west jerusalem killed at least people the tour of dwayat was completed by an israel soldier outside of service shot and killed.',
#  'He asked me to help you.',
#  'algerian security authorities summoned algerian cartoonist tahir ghesh who is facing charges of insulting the president of the republic and insulting him via electronic media and crowdsourcing after posting cartoons against rock gas mining practices in ein saleh city.',
#  'the list was submitted following the passage of the federal law which required websites to store descriptions of all russian users information about the arrival of audio data and their transmission and commissioning as well as written texts photos and other such things and access to them by russian authorities websites can avoid such information by giving russian officials absolute and enduring access to their data.',
#  'august.',
#  'cooperation between haiti and cuba global voices.',
#  "They've elected a new government.",
#  'madagascar the rapitoto.',
#  'the police will take it seriously if there are people who will take it seriously.',
#  'Where will it be Monday?',
#  "What's your address?",
#  'this post is based on joint research by newsrooms in france and the uk through crosscheck french english a non profit website to combat disinformation online and is republished here under a partnership to share content.',
#  'Will you go to America next month?',
#  "I didn't understand the joke he told us.",
#  'related links.',
#  'the first photo of a great vending machine at least from a japanese perspective from hituki nacagawa the director of the ashi chimbon office in vladivostok a well respected daily newspaper sells the vending machine found in the caviar photo at the cost.',
#  'aleppo s recent fall may be in the wake of an orphan s revolution assad s victory means the end of the once democratic aleppo civic experiment lighting hope which means that hundreds more civil society activists medical workers and relief workers who will join thousands of people in jail will not be able to return to their homes refugees and displaced people will not be able to return to their homes the extremist groups will increase their strength and will not be subject to popular pressure and that will mean return to the kingdom of fear.',
#  'Sport is useful for health.',
#  'The robbery was wrong.',
# ...
#  'Can you hear me?',
#  'yesterday i featured all the feelings of childhood when i watched the worldwide video of the man who climbed a building from four floors in less than seconds to save the child the hashtag used.',
#  "I'm sure Tom will do that.",
#  'aleppo a message about the world to morskh in the future global voices.',
#  "Let's not get ahead of ourselves.",
#  'I just arrived.',
#  'He lived next to his uncle.',
#  'I know it was dangerous.',
#  'every four minutes a woman is the victim of domestic violence in brazil as i point out during a meeting at the state attorney general s office of rio grande do sol on march.',
#  'A lot of trees fell down.',
#  "Tom doesn't like Mary's behavior.",
#  'Please distribute the cards.',
#  'I work at a language school.',
#  'we are posting some photos here.',
#  'with everything we have in need of a solution and a confrontation does it make sense for the country to start discussing marijuana is this the right time president.',
#  "I'm from Ecuador.",
#  'more than people including five afghan lawmakers and a number of children were killed on tuesday in one of the biggest suicide attacks since the fall of talibans afghan officials said several bloggers are writing about their questions and sharing opinions on the subject.',
#  'kazaur de insanttes a moment hunter posts a video post for a weekend in iturpe paraguay.',
#  'in addition to this new way of monitoring the internet beijing police are distributing posters on internet cafes entrances with the clear intention of intimidating internet users see the picture below.',
#  'singapore bloggers angry at internet service provider global voices.',
#  'over the past decades much research has been carried out on the phenomenon but most of its findings have not been widely shared in this regard youtube colombia is trying to research the phenomenon in spanish through the seven episode series entitled killing the tragedy of latin america.',
#  'in the following video the mother cries her son who was sent on a mission to afghanistan for six months apparently according to the son has increased.',
#  'He took advantage of every opportunity.',
#  'iranian cartoonist mahmoud shokrayi has once been sentenced to lashes for caricatures of former mayor of the chamber of deputies ahmed lotfi ishtani in the magazine of amir name in irak city.',
#  'as well as being a crowd meeting where editors authors and translators of global voices discuss their ideas a number of selected universities from around the world are invited to share their knowledge and learn from our community.',
#  'Are you sure you know how to do this?',
#  'rosean lake reveals why it is difficult to say i love chinese people in their native language from a historical and social perspective it also offers an experience about chinese brain and its connection to love and romance.',
#  "I wasn't there.",
#  'babac dadad writes in a post in fa.',
#  'The sauce was too hot, it burned my tongue.',
#  "I'll take this.",
#  "Don't worry about it.",
#  "I'm going to the park.",
#  'Do it now.',
#  'latin america art from colonial times global voices.',
#  'saudi blogger ahmed al omran compiled a series of videos on the storybook website of storifei allegedly leaked from syria on friday the protests that took place on that day showed a warning some of the videos contained live sightings.',
#  'what is encouraging the kidnapping thanks to the one child s policy china traditions that pressure families to have children kidnapped children are often sold to new families on the other hand kidnapped girls are sold in areas where there are too many single men as well as many are sold to show on the streets begging or prostitution.',
#  'the philippines government has created a table that shows the quality of the country s national roads and uploads them online the table is a tool for citizens to monitor and report bad roads.',
#  'This is an old book.',
#  'Tom is waiting at the airport.',
#  'the second scenario is a popular rage that surrounds the country and blasts the situation or there may be power struggles who knows we might see a version of north korea s northern korean version of ahne jong jion kim gao kyoo kim jong jun a south korean activist assassinated the japanese prime minister who was eager to join south korean japan s southern korean army kim gao kyoo is a south korean general who assassinated former south korean president park chong he remembers as a dictator.',
#  "We have to get him to the hospital before it's too late.",
#  'the blog features an interactive map that enables readers to track the journey and see related stories.',
#  'When do you start?',
#  'subscribe to the e mail list of digital natives to contribute to the digital native please complete this form.',
#  'islam karimov the president of uzbekistan is difficult to remove he prefers not to sing but he dances.',
#  'May I sit down?',
#  'another tea station to keep protesters warm photo by user clashut.',
#  'The car crashed into the wall.',
#  'learn how to make different bags using a square of fabric and a contract known as japan.',
#  'She really came here.',
#  'Who are those?',
#  'photo by iguenie xininen cc by nc sa.',
#  'your donation to us will help support the efforts of our authors and translators who work around the clock to bring the latest news from areas of conflict disaster and struggles for freedom of expression.',
#  'Hurry up to the train station.',
#  'domestic violence in armenia is one of the taboos for a long time but when a year old mother zarhouhi petrosyan was beaten to death in october individuals and organizations took action to challenge this issue affecting more than a quarter of armenian women.',
#  'so the fall ends very quickly and spring ends the sunshine days we ve had in october and in early november will soon be replaced by the winter rain that will be washed away by the fall stencils.',
#  'Do you have a product gallery in the city?',
#  'facebook activists launched a facebook page to denounce the law and demand its overthrow and called for a parliamentary presence on the day when it was discussed and approved.',
#  'Bring me something to eat.',
#  'among the services that have broken down are blogspot hang ut and google draev and photo services including gmail subtitles.',
#  'They searched every way trying to avoid war.',
#  'iran new sex scandal through individual journalism global voices.',
#  'we go there just to participate and match numbers the london games will also help us expose our athletes for the future we wish them success.',
#  'the death of three colds in lebanon global voices.',
#  'philippines national media list global voices.',
#  'Tom made a mistake.',
#  'turkey insulting turk global voices.',
#  'This is where the battle is.',
#  'Can you give me your full name?',
#  'more photos with the free syrian army in free syria have tanks now.',
#  "It's been ten years since she died.",
#  "He's handsome and clever.",
#  'chinese are angry with the train tickets website global voices.',
#  'india perspectives on india s development global voices.',
#  'sanaa from the american nude blog comments on a academic study on the future of qatar al jazeera channel in the united states.',
#  'the lights are very easy to repeat as they spread around the world the next video shows their use in mexico heinha and indigenous people in remote communities in chilean countries.',
#  'Let her know.',
#  'Lolphine is a type of mastectomy.',
#  'c dictatorship and disrespect for rights.',
#  'He can become a hero of the world.',
#  'If I had known!',
#  'the blogger continues what niedo wrote and says.',
#  'zahra campaign in iran.',
#  'We arrived first.',
#  "I think you're right.",
#  'other demonstrations organized later by groups from different backgrounds we are showing in the following video recent excerpts of anti racism protests that took place on august pathina supports most of the time refugees.',
#  'according to the iraqi alternative their sources in sadr city sent a message saying that the attacked forces are preparing to hit the city with a poison gas other than the boy obiat ventanil the same gas that the russians used to attack rebels in moscow theater in.',
#  'as an expression of many feelings for this election another citizen turned down his voice and wrote i am not forced to choose between a murderer and a traitor the regime of the military is a tribute to the martyrs photo by baton facebook.',
#  'It was nice of you to lend me an umbrella.',
#  'Is this your car?',
#  'millions of syrians displaced by the war rely on services to stay in touch with relatives photo by samir dabul via.',
#  'iranian justice does not have a prosecution by serving such punishment as it does against human dignity to get a man to dress as a woman nothing you find in the laws of an islamic republic.',
#  'a blogger comments on the world livelihood index from the economist where karachi confirms itself among the less habitable cities.',
#  "Maybe you'll tell me where I can find Tom.",
#  'You look like a boy.',
#  'yemen s women rebels have been protesting daily alongside men in yemen s streets and squares.',
#  'You can speak.',
#  'Listen carefully.',
#  "Tom doesn't like cheese.",
#  'tajik.',
#  'I was looking for the control.',
#  'I like candlelight.',
#  'Stay with us.',
#  'algeria in memory of the ceasefire authorities block a facebook rally to celebrate the occasion global voices.',
#  'the image used as a background for the sound cloud audio video is a screenshot of a youtube video by saund cloud.',
#  'a blogger writes that around iranian bloggers have signed a petition denouncing the censorship policy and demanding freedom of expression.',
#  "I've learned a lot.",
#  'we look forward to your support and collaboration.',
#  'independent websites have also played an important role in covering the mexican presidential election on july as an alternative to the official media which was accused of being biased towards potential candidate enrique pina nieto the fact that news sites such as polixo and sanambaro and y ne de polixo have proven investigative reports and analysis.',
#  'syria blogging in syria global voices.',
#  'When did you start learning German?',
#  'when the commentator asked if he had to give up officially chomatov promised to continue fighting and blue bucket volunteers would continue collecting information about traffic violations photo and video documenting highway abuses and indeed every month blue bucket members drive their cars in a car demonstration holding blue buckets mocking sirens used by state official officials.',
#  'another use of technology worth mentioning is the creation of a photo collection on flickr which has the name of the torturers encyclopedia which contains photos of police officers some of whom are accused of human rights violations the group runs a number of egyptian bloggers and all of whose contributions are open to everyone to watch and the facebook page torture in egypt also features an interactive ad hoc map that tracks cases of torture in different parts of egypt and allows users to send reports about new torture crimes to show the facts of these violations in a transparent way the website also makes it easier to search for the crimes of torture and various violence occurring in any city in all parts of egypt.',
#  'a look at the indian university in venezuela global voices.',
#  'gary sauer thomson on the other hand criticized the lack of courage of the rudd government.',
#  'three tons of anchovies in the mejillones bay.',
#  'other human rights projects.',
#  'working with an indigenous community to teach and encourage new generations of them to use twitter to connect with others as a way to preserve and promote their native language online.',
#  "It's like this car is his.",
#  'khrofa from kuwait posts some artwork from the students who learned to celebrate kuwait national day.',
#  "I haven't eaten anything since this morning, actually.",
#  'ethan zuckerman co founder global voices.',
#  'lc the police are subject to much criticism among other things for their assertion of racism through racial profiling how do you translate into this criticism by being a member of the police force.',
#  'Why is it so hot?',
#  'syrian refugees registered in november report by the shoon supreme commission for refugees.',
#  'friday of march was a tragic time in yemen s history and this day will be dug in the memory of every yemeni named friday th on this date yemeni security forces built a wall around the change square in sanaa and then painted by car planes and painted with fuel immediately after the friday prayers ended they set it off with the goal of holding the rebels in the square at the same time as supporters of sale former president ali abdullah saleh shared on rooftops houses and in the streets of the crowds of fire on the march causing the mass march to spread blood.',
#  "I don't think he's coming.",
#  "I'll call you.",
#  'former prime minister d mahathir ben mohamed s daughter marina updates us on the health of her father who is under heart surgery in the capital city of Kuala Lumpur.',
#  "Here's your health.",
#  'I love him very much.',
#  'seven color underwear.',
#  'We talked for a while.',
#  'Tom wants me to say that.',
#  'after the olympic games this environmental movement will continue china cannot retreat now people know what to do and organizations like our organization are playing a greater role in society.',
#  'attorney general fridi sintroun points out the defeat of the permanent constitution in peru it was the beginning of the end of the liberation from this moment and later his dream as a house of paper was condemned and exiled in colombia where he died of tuberculosis in.',
#  'jose hackel wrote this interview and was first published on june and is republished here as part of the br and global voices partnership.',
#  'iraq respect women global voices.',
#  'the use of metaphors metaphors and equivalents makes it even more difficult for surveillance programs the term hashtag can be used by a person as a corner of a particular person and only one can understand it better understands the context in which it is present.',
#  'May I interrupt?',
#  'this post is part of our special coverage syria protests.',
#  "Why isn't Tom here?",
#  'I broke the door because I lost the key.',
#  "It's going to be too hot today.",
#  'in the village of the khash province of afaal abdel the top candidates for the ballot papers were all women while everyone reported that women s political participation in sistan paluchistan is due to an increase in drug addiction among men and their presence in jail making them unable to run for the elections women s political participation is the result of the efforts of civil society and the local government to oversee women s representation in the political office.',
#  'the next day in light of the occupation of indigenous peoples as well as the granting of six months security for the creation of a special committee to discuss the proposed amendment the chamber of deputies announced the creation of a working group on indigenous affairs a group will be formed by ten previously appointed congressmen and indigenous representatives.',
#  "i'm not worried about my family they have a rice reserve for several months.",
#  "I'd like to know her name.",
#  'philthir s gift.',
#  'This book has not yet been translated into French.',
#  'I suggest you do what Tom says.',
#  'this is closely related to the potential impact of open source software in developing countries where faith in this potential could bring attention to the government side of protecting this emerging industry.',
#  'I love you.',
#  'surrounded by china from the north and a number of southeast asia countries the south china sea covers an estimated million square meters the value of goods that go through its water route is estimated at billion us dollars the area is rich in oil and gas.',
#  "That's what makes me happy.",
#  'The signal was red.',
#  ...]

# %%
# !zip -r FineTunedTransformer.zip /content/FineTunedTransformer
# Out:
#   adding: content/FineTunedTransformer/ (stored 0%)
#   adding: content/FineTunedTransformer/special_tokens_map.json (deflated 35%)
#   adding: content/FineTunedTransformer/target.spm (deflated 49%)
#   adding: content/FineTunedTransformer/vocab.json (deflated 77%)
#   adding: content/FineTunedTransformer/training_args.bin (deflated 51%)
#   adding: content/FineTunedTransformer/config.json (deflated 61%)
#   adding: content/FineTunedTransformer/tokenizer_config.json (deflated 68%)
#   adding: content/FineTunedTransformer/source.spm (deflated 55%)
#   adding: content/FineTunedTransformer/generation_config.json (deflated 43%)
#   adding: content/FineTunedTransformer/model.safetensors (deflated 7%)
